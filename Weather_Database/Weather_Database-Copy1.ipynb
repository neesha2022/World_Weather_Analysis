# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/neesha/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/neesha/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from citipy) (0.16)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 586

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d2160cf782ea3e0001ff3f8bc404fb00

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | mayo
# Processing Record 3 of Set 1 | shingu
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | balakovo
# Processing Record 6 of Set 1 | kishni
# Processing Record 7 of Set 1 | ajdabiya
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | victoria
# Processing Record 10 of Set 1 | atar
# Processing Record 11 of Set 1 | paamiut
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | padang
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | kaitangata
# Processing Record 16 of Set 1 | bengkulu
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | jaen
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | tsentralnyy
# City not found. Skipping...
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | mecca
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | kisanga
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | prescott
# Processing Record 32 of Set 1 | estelle
# Processing Record 33 of Set 1 | cumberland
# Processing Record 34 of Set 1 | bandiagara
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | nivala
# Processing Record 37 of Set 1 | ancud
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 1 | abu dhabi
# Processing Record 41 of Set 1 | maragogi
# Processing Record 42 of Set 1 | taoudenni
# Processing Record 43 of Set 1 | todos santos
# Processing Record 44 of Set 1 | nong ki
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | salalah
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | eureka
# Processing Record 3 of Set 2 | mehamn
# Processing Record 4 of Set 2 | pietarsaari
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | talnakh
# Processing Record 8 of Set 2 | westport
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | kutum
# Processing Record 12 of Set 2 | grindavik
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | virginia beach
# Processing Record 15 of Set 2 | miri
# Processing Record 16 of Set 2 | hasaki
# Processing Record 17 of Set 2 | avarua
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | toamasina
# Processing Record 20 of Set 2 | humaita
# Processing Record 21 of Set 2 | pundaguitan
# Processing Record 22 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | la primavera
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | berlevag
# Processing Record 29 of Set 2 | ramasukha
# City not found. Skipping...
# Processing Record 30 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | rundu
# Processing Record 33 of Set 2 | jerez
# Processing Record 34 of Set 2 | preobrazheniye
# Processing Record 35 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | minab
# Processing Record 39 of Set 2 | cherskiy
# Processing Record 40 of Set 2 | half moon bay
# Processing Record 41 of Set 2 | pringsewu
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | axim
# Processing Record 44 of Set 2 | misratah
# Processing Record 45 of Set 2 | barcelos
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | sogdiondon
# City not found. Skipping...
# Processing Record 48 of Set 2 | santa maria
# Processing Record 49 of Set 2 | leshukonskoye
# Processing Record 50 of Set 2 | chapais
# Processing Record 1 of Set 3 | coquimbo
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | megion
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 3 | broome
# Processing Record 7 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 3 | grand gaube
# Processing Record 9 of Set 3 | mount gambier
# Processing Record 10 of Set 3 | novodugino
# Processing Record 11 of Set 3 | narsaq
# Processing Record 12 of Set 3 | awjilah
# Processing Record 13 of Set 3 | agropoli
# Processing Record 14 of Set 3 | college
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | bonthe
# Processing Record 17 of Set 3 | puerto ayora
# Processing Record 18 of Set 3 | chincha alta
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | abu samrah
# Processing Record 21 of Set 3 | carman
# Processing Record 22 of Set 3 | gornopravdinsk
# Processing Record 23 of Set 3 | east london
# Processing Record 24 of Set 3 | izberbash
# Processing Record 25 of Set 3 | dakar
# Processing Record 26 of Set 3 | long beach
# Processing Record 27 of Set 3 | nichinan
# Processing Record 28 of Set 3 | lavrentiya
# Processing Record 29 of Set 3 | carutapera
# Processing Record 30 of Set 3 | baykit
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | barra da estiva
# Processing Record 33 of Set 3 | bourail
# Processing Record 34 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | kahone
# Processing Record 37 of Set 3 | tiksi
# Processing Record 38 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 3 | conceicao do araguaia
# Processing Record 40 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 3 | bogatoye
# Processing Record 42 of Set 3 | ahipara
# Processing Record 43 of Set 3 | bilibino
# Processing Record 44 of Set 3 | bubaque
# Processing Record 45 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 3 | moussoro
# Processing Record 47 of Set 3 | necochea
# Processing Record 48 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 3 | nishihara
# Processing Record 50 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | emerald
# Processing Record 3 of Set 4 | souillac
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | tucson
# Processing Record 6 of Set 4 | freetown
# Processing Record 7 of Set 4 | altamira
# Processing Record 8 of Set 4 | lompoc
# Processing Record 9 of Set 4 | atyrau
# Processing Record 10 of Set 4 | mapiripan
# Processing Record 11 of Set 4 | talara
# Processing Record 12 of Set 4 | airai
# Processing Record 13 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 4 | durban
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | bilma
# Processing Record 17 of Set 4 | kibre mengist
# Processing Record 18 of Set 4 | deputatskiy
# Processing Record 19 of Set 4 | port hardy
# Processing Record 20 of Set 4 | solnechnyy
# Processing Record 21 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 4 | ambikapur
# Processing Record 23 of Set 4 | muros
# Processing Record 24 of Set 4 | hobyo
# Processing Record 25 of Set 4 | gao
# Processing Record 26 of Set 4 | hirara
# Processing Record 27 of Set 4 | vila velha
# Processing Record 28 of Set 4 | kabugao
# Processing Record 29 of Set 4 | ailigandi
# Processing Record 30 of Set 4 | barrow
# Processing Record 31 of Set 4 | los llanos de aridane
# Processing Record 32 of Set 4 | moche
# Processing Record 33 of Set 4 | port hedland
# Processing Record 34 of Set 4 | kloulklubed
# Processing Record 35 of Set 4 | marsa matruh
# Processing Record 36 of Set 4 | clyde river
# Processing Record 37 of Set 4 | zyrardow
# Processing Record 38 of Set 4 | saint-pierre
# Processing Record 39 of Set 4 | atherton
# Processing Record 40 of Set 4 | kolyshley
# Processing Record 41 of Set 4 | cuamba
# Processing Record 42 of Set 4 | mackay
# Processing Record 43 of Set 4 | iqaluit
# Processing Record 44 of Set 4 | zyryanka
# Processing Record 45 of Set 4 | batagay
# Processing Record 46 of Set 4 | gat
# Processing Record 47 of Set 4 | esperance
# Processing Record 48 of Set 4 | wanaka
# Processing Record 49 of Set 4 | khorramshahr
# Processing Record 50 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 5 | vila franca do campo
# Processing Record 2 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 5 | gazli
# Processing Record 4 of Set 5 | codrington
# Processing Record 5 of Set 5 | tombouctou
# Processing Record 6 of Set 5 | new norfolk
# Processing Record 7 of Set 5 | danville
# Processing Record 8 of Set 5 | praya
# Processing Record 9 of Set 5 | flinders
# Processing Record 10 of Set 5 | provideniya
# Processing Record 11 of Set 5 | canto do buriti
# Processing Record 12 of Set 5 | maningrida
# Processing Record 13 of Set 5 | varzea da palma
# Processing Record 14 of Set 5 | sheregesh
# Processing Record 15 of Set 5 | hilo
# Processing Record 16 of Set 5 | alice springs
# Processing Record 17 of Set 5 | port blair
# Processing Record 18 of Set 5 | benjamin constant
# Processing Record 19 of Set 5 | bonavista
# Processing Record 20 of Set 5 | susanville
# Processing Record 21 of Set 5 | bafra
# Processing Record 22 of Set 5 | loyga
# Processing Record 23 of Set 5 | brae
# Processing Record 24 of Set 5 | yulara
# Processing Record 25 of Set 5 | marawi
# Processing Record 26 of Set 5 | gimbi
# Processing Record 27 of Set 5 | aykhal
# Processing Record 28 of Set 5 | mandalgovi
# Processing Record 29 of Set 5 | tura
# Processing Record 30 of Set 5 | rovaniemi
# Processing Record 31 of Set 5 | ekibastuz
# Processing Record 32 of Set 5 | cockburn town
# Processing Record 33 of Set 5 | tuatapere
# Processing Record 34 of Set 5 | beringovskiy
# Processing Record 35 of Set 5 | piranhas
# Processing Record 36 of Set 5 | tabou
# Processing Record 37 of Set 5 | fairlie
# Processing Record 38 of Set 5 | banbury
# Processing Record 39 of Set 5 | sibolga
# Processing Record 40 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 5 | payakumbuh
# Processing Record 42 of Set 5 | te anau
# Processing Record 43 of Set 5 | maceio
# Processing Record 44 of Set 5 | yichang
# Processing Record 45 of Set 5 | svirstroy
# Processing Record 46 of Set 5 | puerto lleras
# Processing Record 47 of Set 5 | tuktoyaktuk
# Processing Record 48 of Set 5 | kholtoson
# Processing Record 49 of Set 5 | parry sound
# Processing Record 50 of Set 5 | shumskiy
# Processing Record 1 of Set 6 | luwingu
# Processing Record 2 of Set 6 | dumai
# Processing Record 3 of Set 6 | saldanha
# Processing Record 4 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 5 of Set 6 | calamar
# Processing Record 6 of Set 6 | georgetown
# Processing Record 7 of Set 6 | wanning
# Processing Record 8 of Set 6 | tautira
# Processing Record 9 of Set 6 | karcsa
# Processing Record 10 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 6 | kruisfontein
# Processing Record 12 of Set 6 | samfya
# Processing Record 13 of Set 6 | pangkalanbuun
# Processing Record 14 of Set 6 | berbera
# Processing Record 15 of Set 6 | cordele
# Processing Record 16 of Set 6 | saquarema
# Processing Record 17 of Set 6 | norfolk
# Processing Record 18 of Set 6 | north bend
# Processing Record 19 of Set 6 | turje
# Processing Record 20 of Set 6 | parabel
# Processing Record 21 of Set 6 | sorong
# Processing Record 22 of Set 6 | bac can
# City not found. Skipping...
# Processing Record 23 of Set 6 | kendari
# Processing Record 24 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 25 of Set 6 | belmonte
# Processing Record 26 of Set 6 | nemuro
# Processing Record 27 of Set 6 | inhambane
# Processing Record 28 of Set 6 | jardim
# Processing Record 29 of Set 6 | vao
# Processing Record 30 of Set 6 | sale
# Processing Record 31 of Set 6 | anderson
# Processing Record 32 of Set 6 | namatanai
# Processing Record 33 of Set 6 | sweetwater
# Processing Record 34 of Set 6 | tahlequah
# Processing Record 35 of Set 6 | namtsy
# Processing Record 36 of Set 6 | san martin
# Processing Record 37 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 6 | okahandja
# Processing Record 39 of Set 6 | husavik
# Processing Record 40 of Set 6 | sobolevo
# Processing Record 41 of Set 6 | faya
# Processing Record 42 of Set 6 | ponta do sol
# Processing Record 43 of Set 6 | khash
# Processing Record 44 of Set 6 | sao filipe
# Processing Record 45 of Set 6 | viedma
# Processing Record 46 of Set 6 | kavaratti
# Processing Record 47 of Set 6 | el arenal
# Processing Record 48 of Set 6 | labrea
# Processing Record 49 of Set 6 | muisne
# Processing Record 50 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | roald
# Processing Record 2 of Set 7 | bloomington
# Processing Record 3 of Set 7 | umtata
# Processing Record 4 of Set 7 | vilhena
# Processing Record 5 of Set 7 | den helder
# Processing Record 6 of Set 7 | vigrestad
# Processing Record 7 of Set 7 | sarishabari
# Processing Record 8 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 7 | portland
# Processing Record 10 of Set 7 | banda aceh
# Processing Record 11 of Set 7 | belyy yar
# Processing Record 12 of Set 7 | wad madani
# Processing Record 13 of Set 7 | adrar
# Processing Record 14 of Set 7 | gigmoto
# Processing Record 15 of Set 7 | sulina
# Processing Record 16 of Set 7 | kokorevka
# Processing Record 17 of Set 7 | alofi
# Processing Record 18 of Set 7 | lingao
# Processing Record 19 of Set 7 | saint george
# Processing Record 20 of Set 7 | mufulira
# Processing Record 21 of Set 7 | namibe
# Processing Record 22 of Set 7 | marzuq
# Processing Record 23 of Set 7 | sampit
# Processing Record 24 of Set 7 | saskylakh
# Processing Record 25 of Set 7 | hithadhoo
# Processing Record 26 of Set 7 | rio grande
# Processing Record 27 of Set 7 | pisco
# Processing Record 28 of Set 7 | teguise
# Processing Record 29 of Set 7 | fortuna
# Processing Record 30 of Set 7 | sola
# Processing Record 31 of Set 7 | sibu
# Processing Record 32 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 7 | chiredzi
# Processing Record 34 of Set 7 | okhotsk
# Processing Record 35 of Set 7 | almaznyy
# Processing Record 36 of Set 7 | nanakuli
# Processing Record 37 of Set 7 | idah
# Processing Record 38 of Set 7 | ajtos
# Processing Record 39 of Set 7 | khani
# Processing Record 40 of Set 7 | jand
# Processing Record 41 of Set 7 | venado tuerto
# Processing Record 42 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 7 | kaseda
# Processing Record 44 of Set 7 | balkanabat
# Processing Record 45 of Set 7 | ilulissat
# Processing Record 46 of Set 7 | senneterre
# Processing Record 47 of Set 7 | renqiu
# Processing Record 48 of Set 7 | shizilu
# Processing Record 49 of Set 7 | nara
# Processing Record 50 of Set 7 | lincoln
# Processing Record 1 of Set 8 | klaksvik
# Processing Record 2 of Set 8 | maniitsoq
# Processing Record 3 of Set 8 | bagaha
# Processing Record 4 of Set 8 | atikokan
# Processing Record 5 of Set 8 | atbasar
# Processing Record 6 of Set 8 | hualmay
# Processing Record 7 of Set 8 | vicuna
# Processing Record 8 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 8 | payo
# Processing Record 10 of Set 8 | nago
# Processing Record 11 of Set 8 | poya
# Processing Record 12 of Set 8 | ribeira grande
# Processing Record 13 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 14 of Set 8 | kalianget
# Processing Record 15 of Set 8 | kijang
# Processing Record 16 of Set 8 | pochutla
# Processing Record 17 of Set 8 | bereda
# Processing Record 18 of Set 8 | san patricio
# Processing Record 19 of Set 8 | dudinka
# Processing Record 20 of Set 8 | vanimo
# Processing Record 21 of Set 8 | port lincoln
# Processing Record 22 of Set 8 | coihaique
# Processing Record 23 of Set 8 | raudeberg
# Processing Record 24 of Set 8 | komsomolskiy
# Processing Record 25 of Set 8 | benicarlo
# Processing Record 26 of Set 8 | tambovka
# Processing Record 27 of Set 8 | amapa
# Processing Record 28 of Set 8 | coahuayana
# Processing Record 29 of Set 8 | sur
# Processing Record 30 of Set 8 | kamen-rybolov
# Processing Record 31 of Set 8 | the valley
# Processing Record 32 of Set 8 | praia
# Processing Record 33 of Set 8 | suez
# Processing Record 34 of Set 8 | loukhi
# Processing Record 35 of Set 8 | ha giang
# Processing Record 36 of Set 8 | cascavel
# Processing Record 37 of Set 8 | san lawrenz
# Processing Record 38 of Set 8 | dabat
# Processing Record 39 of Set 8 | chuy
# Processing Record 40 of Set 8 | vizinga
# Processing Record 41 of Set 8 | teya
# Processing Record 42 of Set 8 | swedru
# Processing Record 43 of Set 8 | cap malheureux
# Processing Record 44 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 8 | pa sang
# Processing Record 46 of Set 8 | ostrovnoy
# Processing Record 47 of Set 8 | ocos
# Processing Record 48 of Set 8 | simbahan
# Processing Record 49 of Set 8 | bathsheba
# Processing Record 50 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 9 | limpapa
# Processing Record 3 of Set 9 | lianzhou
# Processing Record 4 of Set 9 | kosa
# Processing Record 5 of Set 9 | pakhtakoron
# Processing Record 6 of Set 9 | tuy hoa
# Processing Record 7 of Set 9 | halifax
# Processing Record 8 of Set 9 | cabo san lucas
# Processing Record 9 of Set 9 | micomeseng
# Processing Record 10 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 9 | alugan
# Processing Record 12 of Set 9 | vaitape
# Processing Record 13 of Set 9 | ucluelet
# Processing Record 14 of Set 9 | katsuura
# Processing Record 15 of Set 9 | lewistown
# Processing Record 16 of Set 9 | asyut
# Processing Record 17 of Set 9 | mongo
# Processing Record 18 of Set 9 | kardla
# Processing Record 19 of Set 9 | lindi
# Processing Record 20 of Set 9 | bopfingen
# Processing Record 21 of Set 9 | rock springs
# Processing Record 22 of Set 9 | bograd
# Processing Record 23 of Set 9 | leningradskiy
# Processing Record 24 of Set 9 | san quintin
# Processing Record 25 of Set 9 | nixa
# Processing Record 26 of Set 9 | uray
# Processing Record 27 of Set 9 | aklavik
# Processing Record 28 of Set 9 | palu
# Processing Record 29 of Set 9 | nioro
# Processing Record 30 of Set 9 | zhigansk
# Processing Record 31 of Set 9 | fairbanks
# Processing Record 32 of Set 9 | syracuse
# Processing Record 33 of Set 9 | dodge city
# Processing Record 34 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 9 | adeje
# Processing Record 36 of Set 9 | tabatinga
# Processing Record 37 of Set 9 | saint-georges
# Processing Record 38 of Set 9 | okha
# Processing Record 39 of Set 9 | skarzysko-kamienna
# Processing Record 40 of Set 9 | sitka
# Processing Record 41 of Set 9 | ligayan
# Processing Record 42 of Set 9 | comodoro rivadavia
# Processing Record 43 of Set 9 | itoman
# Processing Record 44 of Set 9 | waipawa
# Processing Record 45 of Set 9 | shostka
# Processing Record 46 of Set 9 | sabang
# Processing Record 47 of Set 9 | geraldton
# Processing Record 48 of Set 9 | general roca
# Processing Record 49 of Set 9 | steamboat springs
# Processing Record 50 of Set 9 | kabelvag
# Processing Record 1 of Set 10 | guerrero negro
# Processing Record 2 of Set 10 | waingapu
# Processing Record 3 of Set 10 | kushmurun
# Processing Record 4 of Set 10 | jesenice
# Processing Record 5 of Set 10 | chateauroux
# Processing Record 6 of Set 10 | fez
# Processing Record 7 of Set 10 | hidrolandia
# Processing Record 8 of Set 10 | panaba
# Processing Record 9 of Set 10 | dali
# Processing Record 10 of Set 10 | saint-louis
# Processing Record 11 of Set 10 | tahta
# Processing Record 12 of Set 10 | kalabo
# Processing Record 13 of Set 10 | bakchar
# Processing Record 14 of Set 10 | challans
# Processing Record 15 of Set 10 | achit
# Processing Record 16 of Set 10 | doha
# Processing Record 17 of Set 10 | tokmak
# Processing Record 18 of Set 10 | haines junction
# Processing Record 19 of Set 10 | san jeronimo
# Processing Record 20 of Set 10 | fort nelson
# Processing Record 21 of Set 10 | pokhara
# Processing Record 22 of Set 10 | itaberaba
# Processing Record 23 of Set 10 | poum
# Processing Record 24 of Set 10 | mulege
# Processing Record 25 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 26 of Set 10 | babusnica
# Processing Record 27 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 10 | vardo
# Processing Record 29 of Set 10 | north platte
# Processing Record 30 of Set 10 | baruun-urt
# Processing Record 31 of Set 10 | santiago del estero
# Processing Record 32 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 10 | manggar
# Processing Record 34 of Set 10 | ocean city
# Processing Record 35 of Set 10 | kaspiyskiy
# Processing Record 36 of Set 10 | zhezkazgan
# Processing Record 37 of Set 10 | dickinson
# Processing Record 38 of Set 10 | buraydah
# Processing Record 39 of Set 10 | obo
# Processing Record 40 of Set 10 | poronaysk
# Processing Record 41 of Set 10 | bella vista
# Processing Record 42 of Set 10 | cortez
# Processing Record 43 of Set 10 | piacabucu
# Processing Record 44 of Set 10 | kununurra
# Processing Record 45 of Set 10 | kinsale
# Processing Record 46 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 10 | wajima
# Processing Record 48 of Set 10 | gotemba
# Processing Record 49 of Set 10 | takoradi
# Processing Record 50 of Set 10 | yar-sale
# Processing Record 1 of Set 11 | touros
# Processing Record 2 of Set 11 | pagudpud
# Processing Record 3 of Set 11 | lisakovsk
# Processing Record 4 of Set 11 | changji
# Processing Record 5 of Set 11 | norman wells
# Processing Record 6 of Set 11 | luderitz
# Processing Record 7 of Set 11 | jacareacanga
# Processing Record 8 of Set 11 | high level
# Processing Record 9 of Set 11 | porumbacu de jos
# Processing Record 10 of Set 11 | orodara
# Processing Record 11 of Set 11 | faanui
# Processing Record 12 of Set 11 | sao felix do xingu
# Processing Record 13 of Set 11 | najran
# Processing Record 14 of Set 11 | san cristobal
# Processing Record 15 of Set 11 | sokoni
# Processing Record 16 of Set 11 | dothan
# Processing Record 17 of Set 11 | tonantins
# Processing Record 18 of Set 11 | khandyga
# Processing Record 19 of Set 11 | velikooktyabrskiy
# Processing Record 20 of Set 11 | isangel
# Processing Record 21 of Set 11 | kafanchan
# Processing Record 22 of Set 11 | stornoway
# Processing Record 23 of Set 11 | ambilobe
# Processing Record 24 of Set 11 | puerto colombia
# Processing Record 25 of Set 11 | delhi
# Processing Record 26 of Set 11 | daru
# Processing Record 27 of Set 11 | sosnovoborsk
# Processing Record 28 of Set 11 | kahului
# Processing Record 29 of Set 11 | vidim
# Processing Record 30 of Set 11 | chara
# Processing Record 31 of Set 11 | bam
# Processing Record 32 of Set 11 | harper
# Processing Record 33 of Set 11 | naze
# Processing Record 34 of Set 11 | dubti
# Processing Record 35 of Set 11 | beloha
# Processing Record 36 of Set 11 | cidreira
# Processing Record 37 of Set 11 | beitbridge
# Processing Record 38 of Set 11 | tazovskiy
# Processing Record 39 of Set 11 | beryslav
# Processing Record 40 of Set 11 | sistranda
# Processing Record 41 of Set 11 | togur
# Processing Record 42 of Set 11 | lumphat
# Processing Record 43 of Set 11 | saint anthony
# Processing Record 44 of Set 11 | samarai
# Processing Record 45 of Set 11 | kralendijk
# Processing Record 46 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 47 of Set 11 | kenai
# Processing Record 48 of Set 11 | big rapids
# Processing Record 49 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 12 | verkhniy landekh
# Processing Record 2 of Set 12 | bac lieu
# Processing Record 3 of Set 12 | nador
# Processing Record 4 of Set 12 | avera
# Processing Record 5 of Set 12 | mtama
# Processing Record 6 of Set 12 | la paz
# Processing Record 7 of Set 12 | liverpool
# Processing Record 8 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 12 | nikolayevsk-na-amure
# Processing Record 10 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 12 | peruibe
# Processing Record 12 of Set 12 | asilah
# Processing Record 13 of Set 12 | ridgecrest
# Processing Record 14 of Set 12 | achiotal
# City not found. Skipping...
# Processing Record 15 of Set 12 | victoria point
# Processing Record 16 of Set 12 | jumla
# Processing Record 17 of Set 12 | sao jose da tapera
# Processing Record 18 of Set 12 | kargasok
# Processing Record 19 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 20 of Set 12 | sohag
# Processing Record 21 of Set 12 | leh
# Processing Record 22 of Set 12 | naples
# Processing Record 23 of Set 12 | morondava
# Processing Record 24 of Set 12 | jiayuguan
# Processing Record 25 of Set 12 | antofagasta
# Processing Record 26 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 27 of Set 12 | shakawe
# Processing Record 28 of Set 12 | patiya
# Processing Record 29 of Set 12 | mayumba
# Processing Record 30 of Set 12 | aviles
# Processing Record 31 of Set 12 | laguna
# Processing Record 32 of Set 12 | pitsunda
# Processing Record 33 of Set 12 | de-kastri
# Processing Record 34 of Set 12 | borca
# Processing Record 35 of Set 12 | bluffton
# Processing Record 36 of Set 12 | van buren
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 534

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Busselton      AU -33.6500  115.3333     54.79        64          91
# 1         Mayo      US  38.8876  -76.5119     72.36        91         100
# 2       Shingu      JP  33.7333  135.9833     78.40        87          81
# 3       Atuona      PF  -9.8000 -139.0333     77.86        77          23
# 4     Balakovo      RU  52.0278   47.8007     66.40        66          51
# ..         ...     ...      ...       ...       ...       ...         ...
# 529   Pitsunda      GE  43.1592   40.3378     69.98        69           5
# 530  De-Kastri      RU  51.4667  140.7833     62.49        84          99
# 531      Borca      RO  47.1833   25.7667     52.02        89          94
# 532   Bluffton      US  32.2371  -80.8604     77.02        94         100
# 533  Van Buren      US  35.4368  -94.3483     98.62        43          40
#
#      Wind Speed Current Description
# 0         16.71     overcast clouds
# 1          3.44     overcast clouds
# 2          1.32       broken clouds
# 3         18.01          few clouds
# 4          5.14       broken clouds
# ..          ...                 ...
# 529        3.27           clear sky
# 530        8.32     overcast clouds
# 531        1.16     overcast clouds
# 532        6.91        thunderstorm
# 533       12.66    scattered clouds
#
# [534 rows x 9 columns]

# %%
# Create the CSV output file
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
